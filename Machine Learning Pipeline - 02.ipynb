# %%
import pandas as pd 
from datetime import datetime as dt

# %%
df = pd.read_csv("etapa1.csv")

# %%
df.drop(columns=['uid'],inplace=True)

# %%
df['pipeline'] = 'ETAPA 2'
df['dt'] = dt.now()

# %%
df
# Out:
#      id                city        street_name        street_address  \
# 0  1499       Seritachester       Roland Plain      38992 Lyman Ford
# 1  2573         Julietaland      Fredric Roads    24539 Isreal Coves
# 2  7208  East Shantelleland      Wilfred Ridge    155 Franklyn Green
# 3  2573    North Damionstad      Luettgen Fork    1631 Fidela Cliffs
# 4  2173            Judefurt     Stroman Greens  34965 Witting Summit
# 5  6912     Lake Azaleeport         Stokes Rue     52165 Blanda Isle
# 6  6612        Leuschketown  Hodkiewicz Skyway     8348 Mann Highway
# 7  2213          Arleneside        Kihn Manors      9855 Fadel Crest
# 8  3835   North Mozelleland         Tromp Road     95689 Nicol Vista
# 9  1885         East Sharyn        Funk Estate      150 Ratke Plains
#
#   secondary_address  building_number     mail_box         community  \
# 0          Apt. 975             2508   PO Box 277    Autumn Gardens
# 1          Apt. 245             8690  PO Box 7966    Summer Heights
# ...

# %%
df.to_csv("etapa2.csv",index=False)

# %%
pwd
# Out:
# 'C:\\Users\\2104944461\\Documents\\notebooks'
